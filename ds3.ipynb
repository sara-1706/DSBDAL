# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\SARA\Downloads\data-income-age-group.csv")

# %%
df.head()
# Out:
#       Name  Age  Income($)
# 0      Rob   27      70000
# 1  Michael   29      90000
# 2    Mohan   29      61000
# 3   Ismail   28      60000
# 4     Kory   42     150000

# %%
print(df)
# Out:
#         Name  Age  Income($)
# 0        Rob   27      70000
# 1    Michael   29      90000
# 2      Mohan   29      61000
# 3     Ismail   28      60000
# 4       Kory   42     150000
# 5     Gautam   39     155000
# 6      David   41     160000
# 7     Andrea   38     162000
# 8       Brad   36     156000
# 9   Angelina   35     130000
# 10    Donald   37     137000
# 11       Tom   26      45000
# 12    Arnold   27      48000
# 13     Jared   28      51000
# 14     Stark   29      49500
# 15    Ranbir   32      53000
# 16    Dipika   40      65000
# 17  Priyanka   41      63000
# 18      Nick   43      64000
# 19      Alia   39      80000
# 20       Sid   41      82000
# 21     Abdul   39      58000

# %%
print("\ Statistical Summary")
df.describe()
# Out:
# \ Statistical Summary
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# C:\Users\SARA\AppData\Local\Temp\ipykernel_15688\3993870123.py:1: SyntaxWarning: invalid escape sequence '\ '
#   print("\ Statistical Summary")
#              Age      Income($)
# count  22.000000      22.000000
# mean   34.818182   90431.818182
# std     5.901060   43505.964412
# min    26.000000   45000.000000
# 25%    29.000000   58500.000000
# 50%    36.500000   67500.000000
# 75%    39.750000  135250.000000
# max    43.000000  162000.000000

# %%
#defining age groups
bins =[0, 20, 40, 60, 80, 100]
labels =['< 20' , '20-40', '40-60', '60-80', '80+']
df['age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
grouped = df.groupby('Age')['Income($)'].describe()
grouped
# Out:
#      count           mean           std       min       25%       50%  \
# Age
# 26     1.0   45000.000000           NaN   45000.0   45000.0   45000.0
# 27     2.0   59000.000000  15556.349186   48000.0   53500.0   59000.0
# 28     2.0   55500.000000   6363.961031   51000.0   53250.0   55500.0
# 29     3.0   66833.333333  20870.633276   49500.0   55250.0   61000.0
# 32     1.0   53000.000000           NaN   53000.0   53000.0   53000.0
# 35     1.0  130000.000000           NaN  130000.0  130000.0  130000.0
# 36     1.0  156000.000000           NaN  156000.0  156000.0  156000.0
# 37     1.0  137000.000000           NaN  137000.0  137000.0  137000.0
# 38     1.0  162000.000000           NaN  162000.0  162000.0  162000.0
# 39     3.0   97666.666667  50856.005873   58000.0   69000.0   80000.0
# 40     1.0   65000.000000           NaN   65000.0   65000.0   65000.0
# 41     3.0  101666.666667  51403.631519   63000.0   72500.0   82000.0
# ...

# %%
sf =pd.read_csv(r"C:\Users\SARA\Downloads\archive\Iris.csv")

# %%
sf.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
grouped_species = sf.groupby('Species')

# %%
print(" statistical deatils of each species ")
for species, group in grouped_species:
  print("------------------------------------------------------------------------\nStatistics of ", species)
  numeric_group = group.select_dtypes(include=[np.number])
  print("\nMean :")
  print(numeric_group.mean())
  print("\nMinimum value :")
  print(numeric_group.min())
  print("\nStandard Deviation :")
  print(numeric_group.std())
  print("\nPercentiles: ")
  percentiles = np.percentile(numeric_group, (25,50,75) ,axis = 0)
  print(f" 25th percentile : {percentiles[0]} ")
  print(f" 50th percentile : {percentiles[1]} ")
  print(f" 75th percentile : {percentiles[2]} ")
# Out:
#  statistical deatils of each species
# ------------------------------------------------------------------------
# Statistics of  Iris-setosa
#
# Mean :
# Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64
#
# Minimum value :
# Id               1.0
# SepalLengthCm    4.3
# SepalWidthCm     2.3
# PetalLengthCm    1.0
# PetalWidthCm     0.1
# dtype: float64
#
# Standard Deviation :
# Id               14.577380
# SepalLengthCm     0.352490
# SepalWidthCm      0.381024
# PetalLengthCm     0.173511
# PetalWidthCm      0.107210
# dtype: float64
#
# Percentiles:
#  25th percentile : [13.25   4.8    3.125  1.4    0.2  ]
#  50th percentile : [25.5  5.   3.4  1.5  0.2]
#  75th percentile : [37.75   5.2    3.675  1.575  0.3  ]
# ------------------------------------------------------------------------
# Statistics of  Iris-versicolor
#
# Mean :
# Id               75.500
# SepalLengthCm     5.936
# ...
